# %%
print("HOla Mundo Python")
# Out:
# HOla Mundo Python

# %%
print("Numero ", 4)
print("2 + 2 =", 3 + 2)
# Out:
# Numero  4
# 2 + 2 = 5

# %%
nombre = "Maribel"
print(f"Hola {nombre}! Bienvenido a la Programación en Python")
# Out:
# Hola Maribel! Bienvenido a la Programación en Python

# %%
userName = input("¿Cuál es tu nombre? ")
print(f"¡Hola, {userName}! Bienvenido a la Programación en Python")
# Out:
# ¡Hola, Joel! Bienvenido a la Programación en Python

# %%
name = input("¿Cuál es tu nombre? ")
hobby = input("¿Cuál es tu hobby favorito? ")

print("\n--- Mensaje de Bienvenida ---")
print(f"¡Hola, {name}! 👋")
print(f"Bienvenido al mundo de la Programación en Python.")
print(f"Es genial saber que te encanta {hobby}.")
print(f"Prepárate para construir algo increíble hoy.")
# Out:
# --- Mensaje de Bienvenida ---
# ¡Hola, Joel! 👋
# Bienvenido al mundo de la Programación en Python.
# Es genial saber que te encanta Programar.
# Prepárate para construir algo increíble hoy.
