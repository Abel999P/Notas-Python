# %%
#
nombre = "Maribel"
# Python es sensible a las mayusculas a si que nombre es distinto que Nombre
Nombre = "Anna"
edad = 24
altura = 1.65
estudiante = True

print(type(nombre))
print(type(edad))
print(type(altura))
print(type(estudiante))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
edad = "25"
my_edad = edad + 4
print(my_edad)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 edad = "25"
# ----> 2 my_edad = edad + 4
#       3 print(my_edad)
#
# TypeError: can only concatenate str (not "int") to str

# %%
edad = "25"
my_edad = int(edad) + 4
print(my_edad)
# Out:
# 29

# %%
nombre = "Maribel"
print("Hola, mi nombre es", nombre, ", mido", altura, "metros y tengo", edad, "años de edad.")
# Out:
# Hola, mi nombre es Maribel , mido 1.65 metros y tengo 24 años de edad.

# %%
name = input("¿Cuál es tu nombre? ")
age = int(input("¿Cuántos años tienes? "))
color = input("¿Cuál es tu color favorito? ")

print("\n---- Saludo Personalizado ----")
print(f"¡Hola, {name}!")
print(f"¡Tienes {age} años y {color} es un color hermoso!")
print("¡Ya estás listo para comenzar tu aventura en Python")
# Out:
# ---- Saludo Personalizado ----
# ¡Hola, Joel!
# ¡Tienes 27 años y negro es un color hermoso!
# ¡Ya estás listo para comenzar tu aventura en Python
