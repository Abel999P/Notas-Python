# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
contador = 0
while contador < 5:
    print(contador)
    contador += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import time
for i in range(5,0,-1):
    print(i)
    time.sleep(1)
print("¡Despegue!")
# Out:
# 5
# 4
# 3
# 2
# 1
# ¡Despegue!

# %%
import time

entrada = int(input("Ingrese un numero para una cuentra regreasiva"))
print("\n-----Cuenta regresiva-----")

while entrada > 0:
    print(entrada)
    time.sleep(1)
    entrada -= 1

print("¡Despegue!")
# Out:
# -----Cuenta regresiva-----
# 5
# 4
# 3
# 2
# 1
# ¡Despegue!
