# %%
def hola():
    print("Hola Mundo !")
hola()
# Out:
# Hola Mundo !

# %%
def saludar(nombre):
    print(f"Hola {nombre}")
saludar("Juan")
# Out:
# Hola Juan

# %%
import random 

def generar_pregunta_mat():
    num1 = random.randint(1, 10)
    num2 = random.randint(1, 10)
    operador = random.choice(["+", "-", "*", "/"])
    pregunta = f"{num1} {operador} {num2}"

    if operador == "+":
        respuesta = num1 + num2
    elif operador == "-":
        respuesta = num1 - num2
    elif operador == "*":
        respuesta = num1 * num2
    elif operador == "/":
        respuesta = num1 / num2
    return pregunta, respuesta

def main():
    score = 0
    rondas = 2

    print("Pregutnas Matematicas")
    for i in range(rondas):
        pregunta, respuesta = generar_pregunta_mat()
        print(f"Pregunta {i+1}: {pregunta}")
        useRespuesta = input("Tu respuesta: ")

        try:
            if float(useRespuesta) == respuesta:
                print("¡Correcto!")
                score += 1
            else:
                print(f"Incorrecto. La respuesta correcta es: {respuesta}")
        except ValueError:
            print(f"Entrada no válida. La respuesta correcta es: {respuesta}")
    print(f"Tu puntuación final es: {score}/{rondas}")

main()
# Out:
# Pregutnas Matematicas
# Pregunta 1: 9 * 10
# ¡Correcto!
# Pregunta 2: 5 - 10
# Incorrecto. La respuesta correcta es: -5
# Tu puntuación final es: 1/2
