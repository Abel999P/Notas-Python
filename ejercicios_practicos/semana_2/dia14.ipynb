# %%
import math

print(math.sqrt(16))
# Out:
# 4.0

# %%
import random

print(random.randint(1,10))
# Out:
# 3

# %%
from random import choice
print(choice(['apple', 'banana', 'cherry']))
# Out:
# banana

# %%
import random 

password = ''.join(random.choices('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789', k=8))
print(password)
# Out:
# kqmS1EGK

# %%
import random, string

def generar_password(longitud):
    if longitud < 4:
        raise ValueError("La contraseña no puede ser menor de 4 caracteres")
    
    uppercase = string.ascii_uppercase
    lowercase = string.ascii_lowercase
    digits = string.digits
    special_chars = "!@#$%^&*()_+-=[]{}|;:',.<>?/"

    password = [
        random.choice(uppercase),
        random.choice(lowercase),
        random.choice(digits),
        random.choice(special_chars)
    ]

    all_chars = uppercase + lowercase + digits + special_chars
    password += random.choices(all_chars,k=length - 4)

    random.shuffle(password)
    return ''.join(password)

try:
    length = int(input("Ingrese la longitud que desea para su contraseña minimo 4 caracteres"))
    password = generar_password(length)
    print(f"Tu contraseña es: {password}")
except ValueError as e:
    print(e)
# Out:
# Tu contraseña es: 1bAV=
